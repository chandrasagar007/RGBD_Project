# %%
# from keras_segmentation.pretrained import pspnet_50_ADE_20K , pspnet_101_cityscapes, pspnet_101_voc12

# model = pspnet_50_ADE_20K() # load the pretrained model trained on ADE20k dataset

# model = pspnet_101_cityscapes() # load the pretrained model trained on Cityscapes dataset

# model = pspnet_101_voc12() # load the pretrained model trained on Pascal VOC 2012 dataset

# # load any of the 3 pretrained models
# Out:
# Using TensorFlow backend.
# /home/sagar/sagar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sagar/sagar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sagar/sagar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# out = model.predict_segmentation(
#     inp="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/eccv14-data/data/images/img_5001.png",
#     out_fname="out.png"
# )

# %%
import cv2

# %%
from keras_segmentation.models.unet import vgg_unet
# Out:
# Using TensorFlow backend.
# /home/sagar/sagar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sagar/sagar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sagar/sagar/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
model = vgg_unet(n_classes=280 ,  input_height=416, input_width=608  )

model.train(
    train_images =  "/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset4/images_prepped_train/",
    train_annotations = "/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset4/annotations_prepped_train/",
    checkpoints_path = "/tmp/vgg_unet_1" , epochs=10
)
# Out:
#   4%|▍         | 15/381 [00:00<00:02, 144.85it/s]
# Verifying training dataset
# 100%|██████████| 381/381 [00:02<00:00, 144.85it/s]
# Dataset verified!
# WARNING:tensorflow:From /home/sagar/sagar/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/10
# 512/512 [==============================] - 459s 897ms/step - loss: 3.4273 - acc: 0.2521
# saved  /tmp/vgg_unet_1.0
# Epoch 2/10
# 512/512 [==============================] - 457s 892ms/step - loss: 3.0437 - acc: 0.2786
# saved  /tmp/vgg_unet_1.1
# Epoch 3/10
# 512/512 [==============================] - 457s 893ms/step - loss: 2.9951 - acc: 0.2874
# saved  /tmp/vgg_unet_1.2
# Epoch 4/10
# 512/512 [==============================] - 455s 889ms/step - loss: 2.9471 - acc: 0.3007
# ...

# %%
model.save('Segmentataion_v1.h5')

# %%
out = model.predict_segmentation(
    inp="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/eccv14-data/data/images/img_5062.png",
    out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
)

# %%
import matplotlib.pyplot as plt
plt.imshow(out)

# %%
out = model.predict_segmentation(
    inp="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/eccv14-data/data/images/img_5062.png",
    out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
)

# %%
real_annotation = cv2.imread('/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/annotations_prepped_train/img_5062.png')
real_annotation = cv2.cvtColor(real_annotation,cv2.COLOR_BGR2RGB)
real_annotation =cv2.resize(real_annotation,(304,208))

# %%
import matplotlib.pyplot as plt
plt.imshow(out)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(real_annotation)

# %%
out = model.predict_segmentation(
    inp="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/eccv14-data/data/images/img_5068.png",
    out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
)

plt.imshow(out)

# %%
real_annotation = cv2.imread('/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/annotations_prepped_train/img_5068.png')
real_annotation = cv2.cvtColor(real_annotation,cv2.COLOR_BGR2RGB)
real_annotation =cv2.resize(real_annotation,(304,208))
plt.imshow(real_annotation)

# %%
####

# %%
out = model.predict_segmentation(
    inp="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/eccv14-data/data/images/img_5076.png",
    out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
)

plt.imshow(out)

# %%
real_annotation = cv2.imread('/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/annotations_prepped_train/img_5076.png')
real_annotation = cv2.cvtColor(real_annotation,cv2.COLOR_BGR2RGB)
real_annotation =cv2.resize(real_annotation,(304,208))
plt.imshow(real_annotation)

# %%
out = model.predict_segmentation(
    inp="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/eccv14-data/data/images/img_5043.png",
    out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
)

plt.imshow(out)

# %%
real_annotation = cv2.imread('/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/annotations_prepped_train/img_5043.png')
real_annotation = cv2.cvtColor(real_annotation,cv2.COLOR_BGR2RGB)
real_annotation =cv2.resize(real_annotation,(304,208))
plt.imshow(real_annotation)

# %%
out = model.predict_segmentation(
    inp="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/eccv14-data/data/images/img_5056.png",
    out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
)

plt.imshow(out)

# %%
real_annotation = cv2.imread('/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/annotations_prepped_train/img_5056.png')
real_annotation = cv2.cvtColor(real_annotation,cv2.COLOR_BGR2RGB)
real_annotation =cv2.resize(real_annotation,(304,208))
plt.imshow(real_annotation)

# %%
out = model.predict_segmentation(
    inp="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/eccv14-data/data/images/img_5057.png",
    out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
)

plt.imshow(out)

# %%
real_annotation = cv2.imread('/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/annotations_prepped_train/img_5057.png')
real_annotation = cv2.cvtColor(real_annotation,cv2.COLOR_BGR2RGB)
real_annotation =cv2.resize(real_annotation,(304,208))
plt.imshow(real_annotation)

# %%
out = model.predict_segmentation(
    inp="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/eccv14-data/data/images/img_5172.png",
    out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
)

plt.imshow(out)
plt.imsave("img_5171.png",out)

# %%
real_annotation = cv2.imread('/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/annotations_prepped_train/img_5051.png')
real_annotation = cv2.cvtColor(real_annotation,cv2.COLOR_BGR2RGB)
real_annotation =cv2.resize(real_annotation,(304,208))
plt.imshow(real_annotation)

# %%
import os

# %%
for i in os.list.dir('/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/images_prepped_test/'):
    out = model.predict_segmentation(
        inp=os.path.join("/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/images_prepped_test/",str(i)),
        out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-40a14ad4b9ce> in <module>
# ----> 1 for i in os.list.dir('/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/images_prepped_test/'):
#       2     out = model.predict_segmentation(
#       3         inp=os.path.join("/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/images_prepped_test/",str(i)),
#       4         out_fname="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/tmp/out.png"
#       5     )
#
# AttributeError: module 'os' has no attribute 'list'

# %%
print("/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/images_prepped_test"+'img_5051.png'
# Out:
#   File "<ipython-input-37-894499a8107f>", line 1
#     print("/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset3/images_prepped_test"+'img_5051.png'
#                                                                                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
################

# %%
print(model.evaluate_segmentation( inp_images_dir="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset2/images_prepped_train/"  , annotations_dir="/media/sagar/HDD1/IIIT_PGSSP/CV/Project/python/image-segmentation-keras-master/dataset2/annotations_prepped_train/" ) )
# Out:
# 1000it [04:20,  3.83it/s]
# {'frequency_weighted_IU': 0.026690154538375435, 'mean_IU': 0.0040331700814030405, 'class_wise_IU': array([1.11171383e-01, 1.64618206e-03, 3.67636383e-02, 4.44692848e-02,
#        7.25196869e-02, 7.25778332e-02, 5.80370288e-06, 4.34939896e-02,
#        5.27878918e-03, 3.12748368e-04, 2.87311103e-04, 1.43737062e-04,
#        1.06874580e-02, 2.80821046e-06, 9.37858858e-05, 0.00000000e+00,
#        6.52354445e-07, 3.30930303e-04, 4.64093116e-04, 1.47846559e-03,
#        9.94236412e-07, 3.84538970e-06, 1.46523807e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.18349323e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%